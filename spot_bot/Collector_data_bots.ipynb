#nltk.download('stopwords')

# %%
# Original code, stored in 'twitter_credentials.py':
' #---------------------- END ORIGINAL FILE -----------------------

# Work-around:
class twitter_creds:
    def __init__(self, credential_list):
        self.CONSUMER_KEY = credential_list[0]#CONSUMER_KEY
        self.CONSUMER_SECRET = credential_list[1]#CONSUMER_SECRET
        self.ACCESS_TOKEN = credential_list[2]#ACCESS_TOKEN
        self.ACCESS_TOKEN_SECRET = credential_list[3]#ACCESS_TOKEN_SECRET

        
# ***********************************************************************************
# ***********************************************************************************

#                         !! IMPORTANT !!
#                    NEEDS TO BE EDITED BY **YOU**
# Delete the string and replace it with a string containing your specific key
global CONSUMER_KEY
global CONSUMER_SECRET
global ACCESS_TOKEN
global ACCESS_TOKEN_SECRET

CONSUMER_KEY = "cxxxxxxxxxxxxxf"
CONSUMER_SECRET = "xxxxxxxxk"
ACCESS_TOKEN = "41xxxxxxxxxxxxxxxxxxxxxxxM"
ACCESS_TOKEN_SECRET = "1xxxxxxxxx2"
''
# ***********************************************************************************
# ***********************************************************************************

# Keep the rest untouched.
credentials = [CONSUMER_KEY,CONSUMER_SECRET,ACCESS_TOKEN, ACCESS_TOKEN_SECRET]
    
twitter_credentials = twitter_creds(credentials)
print("Consumer key: {}".format(twitter_credentials.CONSUMER_KEY))
print("Access token: {}".format(twitter_credentials.ACCESS_TOKEN))

# %%
# Helper functions
def authenticate_twitter_app():
    
    # Authentication
    consumer_key = twitter_credentials.CONSUMER_KEY 
    consumer_secret = twitter_credentials.CONSUMER_SECRET 
    auth = tp.OAuthHandler(consumer_key, consumer_secret)

    # token stuff
    access_token = twitter_credentials.ACCESS_TOKEN 
    access_token_secret = twitter_credentials.ACCESS_TOKEN_SECRET 
    auth.set_access_token(access_token, access_token_secret)
    return(auth)

def get_user_timeline_tweets(twitter_client, user_list, num_tweets):

    tweets = []
    for user in user_list:
        # This returns tweets & re-tweets, 10 at a time
        # We need to research more about getting larger volume back in time with max_id, since_id, etc.
        print(f'Getting {num_tweets} tweets for {user}. ', end = '')
        try:
            for tweet in tp.Cursor(twitter_client.user_timeline, id=user).items(num_tweets):
                tweets.append(tweet)    
        except tp.RateLimitError:
            print(f'SLEEPING DUE TO RATE LIMIT ERROR!!!!')
            time.sleep(15 * 60)
        except Exception as e:
            print(f'SOME ERROR OCCURRED...PASSING!!!')
            print(e.__doc__)
            pass
    return(tweets)
         
def produce_status_LoDs(statuses):
    
    tweet_LoD = []
    user_LoD = []
    for status in statuses:
        
        tweet_dict = {}
        user_dict = {}
        
        tweet_dict['user_id'] = status.author.id
        tweet_dict['user_screen_name'] = status.author.screen_name
        #tweet_dict['created_at'] = status.created_at.isoformat()
        tweet_dict['created_at'] = str(status.created_at)
        tweet_dict['id'] = status.id
        tweet_dict['id_str'] = status.id_str
        tweet_dict['text'] = status.text
        tweet_dict['source'] = status.source
        tweet_dict['truncated'] = status.truncated
        tweet_dict['retweet_count'] = status.retweet_count
        tweet_dict['favorite_count'] = status.favorite_count
        tweet_dict['lang'] = status.lang
        tweet_dict['is_tweet'] = ((re.search('RT', status.text) == None))
        ###Preimium API only?:  tweet_dict['retweeted_status'] = status.retweeted_status
        ###Preimium API only?:  tweet_dict['reply_count'] = status.reply_count
        ###Premium API only?:  tweet_dict['possibly_sensitive'] = status.possibly_sensitive
        
        tweet_LoD.append(tweet_dict)
                
        # user data
        user_dict['id'] = status.author.id
        #user_dict['id_str'] = status.author.id_str
        user_dict['name'] = status.author.name
        user_dict['screen_name'] = status.author.screen_name
        user_dict['location'] = status.author.location
        #user_dict['url'] = status.author.url
        user_dict['description'] = status.author.description
        user_dict['verified'] = status.author.verified
        user_dict['followers_count'] = status.author.followers_count
        user_dict['listed_count'] = status.author.listed_count
        user_dict['favourites_count'] = status.author.favourites_count
        user_dict['statuses_count'] = status.author.statuses_count
        #user_dict['created_at'] = status.author.created_at.isoformat()
        user_dict['created_at'] = str(status.author.created_at)
        #user_dict['utc_offset'] = status.author.utc_offset
        user_dict['time_zone'] = status.author.time_zone
        user_dict['lang'] = status.author.lang
        
        # Non-twitter, enriched field that dev team is manually managing
        if status.author.verified:
            user_dict['known_bot'] = False
        else:
            user_dict['known_bot'] = False # We will change to true when importing known bots
        user_LoD.append(user_dict)
        
    return(tweet_LoD, user_LoD)

# %%
auth = authenticate_twitter_app()
twitter_client = tp.API(auth)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Jul 14 22:45:11 2018
@authors: andrewcaide and eumarassis
bot list pulled from:
    https://www.nbcnews.com/tech/social-media/now-available-more-200-000-deleted-russian-troll-tweets-n844731
"""

tweets_url = "http://nodeassets.nbcnews.com/russian-twitter-trolls/tweets.csv"
tweets_content = requests.get(tweets_url).content

bots_url = "http://nodeassets.nbcnews.com/russian-twitter-trolls/users.csv"
bots_content = requests.get(bots_url).content

bots = pd.read_csv(io.StringIO(bots_content.decode('utf-8')))
tweets = pd.read_csv(io.StringIO(tweets_content.decode('utf-8')))

#print("Cursory examination of the tweets dataframe:")
#print(tweets.dtypes)

def produce_bot_LoDs(bots, tweets):
    '''
    Read in dataframe of bots and their tweets. Organize them according to Mark's format. 
    
    Args: 
        dataframes - Bots, Tweets
    
    Returns: 
        Cleaned dataframe, with an extra column: 'Bot_Status' = True
    '''
    # Fix tweets:
    tweet_colnames = ['created_at','favorite_count','id','id_str','is_tweet','lang','retweet_count',
                 'source','text','truncated','user_screen_name']
    
    # Ask mark to see if he can pull out hashtags from his tweets!!
    tweets['truncated'] = False
    tweets['is_tweet'] = tweets['text'].apply(lambda x: False if str(x).find('RT') == -1 else True)
    tweets = tweets.rename(columns={'tweet_id': 'id'}) 
    tweets['id_str'] = str(tweets['id'])
    tweets['user_screen_name'] = tweets['user_key']
    tweets['lang'] = 'en'
    #tweets['created_at'] = tweets['created_str']
    
    tweet_output = tweets[tweet_colnames]
    # Fix users:
    user_colnames = ['created_at','description','favourites_count','followers_count','id',
                      'lang','listed_count','location','name','screen_name','statuses_count',
                      'time_zone','verified']
    
    bots_output = bots[user_colnames]
    bots_output['known_bot'] = True
    return(bots_output, tweet_output)

bots_Clean, tweets_Clean = produce_bot_LoDs(bots, tweets)
print(bots_Clean.shape)
# Out:
# (453, 14)

# %%
# This might not run; it has to be executed locally.
user_json  = bots_Clean.to_json(orient='records')
tweet_json = tweets_Clean.to_json(orient='records')


with open('data/b_tweet_table_out.json', 'w') as outfile:  
    json.dump(tweet_json, outfile)
    
with open('data/b_user_table_out.json', 'w') as outfile:  
    json.dump(user_json, outfile)

# Uncomment above if you'd like to save the data.

# %%
# To accurately classify our users, let's pull at least 100 tweets from each account.
num_tweets = 100

# Helper function to get fixed number of tweets and put in results
def get_tweets(twitter_client,v_user_list, num_tweets):
    statuses = get_user_timeline_tweets(twitter_client,v_user_list, num_tweets)
    
    # Create list to write to json file
    tweet_LoD, user_LoD = produce_status_LoDs(statuses)
    
    # Put in DF in case you skip the out/in via json below
    tweet_df = pd.DataFrame(tweet_LoD)
    user_df = pd.DataFrame(user_LoD)
    return(tweet_df, user_df)

# %%
# Get verified users, write them to HD
v_tweet_df, v_user_df  = get_tweets(twitter_client,v_user_list, num_tweets)

user_json = v_user_df.to_json(orient='records')
tweet_json = v_tweet_df.to_json(orient='records')

with open('v_tweet_table_out.json', 'w') as outfile:  
    json.dump(tweet_json, outfile)
with open('v_user_table_out.json', 'w') as outfile:  
    json.dump(user_json, outfile)


# Get unverified users, write them to HD
nv_tweet_df, nv_user_df  = get_tweets(twitter_client,nv_user_list, num_tweets)

user_json = nv_user_df.to_json(orient='records')
tweet_json = nv_tweet_df.to_json(orient='records')

with open('data/v_tweet_table_out.json', 'w') as outfile:  
    json.dump(tweet_json, outfile)
with open('data/v_user_table_out.json', 'w') as outfile:  
    json.dump(user_json, outfile)

# Uncomment above if you'd like to save the data.
# Out:
# Getting 100 tweets for @BarackObama. Getting 100 tweets for @rihanna. Getting 100 tweets for @realDonaldTrump. Getting 100 tweets for @secupp. Getting 100 tweets for @ChairmanKimNK. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @taylorswift13. Getting 100 tweets for @ladygaga. Getting 100 tweets for @TheEllenShow. Getting 100 tweets for @Cristiano. Getting 100 tweets for @YouTube. Getting 100 tweets for @katyperry. Getting 100 tweets for @jtimberlake. Getting 100 tweets for @KimKardashian. Getting 100 tweets for @ArianaGrande. Getting 100 tweets for @britneyspears. Getting 100 tweets for @cnnbrk. Getting 100 tweets for @BillGates. Getting 100 tweets for @narendramodi. Getting 100 tweets for @Oprah. Getting 100 tweets for @SecPompeo. Getting 100 tweets for @nikkihaley. Getting 100 tweets for @SamSifton. Getting 100 tweets for @FrankBruni. Getting 100 tweets for @The_Hank_Poggi. Getting 100 tweets for @krassenstein. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @TheJordanRachel. Getting 100 tweets for @MrsScottBaio. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @ClaireBerlinski. Getting 100 tweets for @java. Getting 100 tweets for @JakeSherman. Getting 100 tweets for @jaketapper. Getting 100 tweets for @jakeowen. Getting 100 tweets for @AndrewCMcCarthy. Getting 100 tweets for @tictoc. Getting 100 tweets for @thedailybeast. Getting 100 tweets for @mitchellvii. Getting 100 tweets for @GadSaad. Getting 100 tweets for @Joy_Villa. Getting 100 tweets for @RashanAGary. Getting 100 tweets for @DallasFed. Getting 100 tweets for @Gab.ai. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @bigleaguepolitics. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Circa. Getting 100 tweets for @EmilyMiller. Getting 100 tweets for @francesmartel. Getting 100 tweets for @andersoncooper. Getting 100 tweets for @nico_mueller. Getting 100 tweets for @NancyGrace. Getting 100 tweets for @washingtonpost. Getting 100 tweets for @ThePSF. Getting 100 tweets for @pnut. Getting 100 tweets for @EYJr. Getting 100 tweets for @MCRofficial. Getting 100 tweets for @RM_Foundation. Getting 100 tweets for @tomwaits. Getting 100 tweets for @burbunny. Getting 100 tweets for @justinbieber. Getting 100 tweets for @TherealTaraji. Getting 100 tweets for @duttypaul. Getting 100 tweets for @AvanJogia. Getting 100 tweets for @AlecJRoss. Getting 100 tweets for @s_vakarchuk. Getting 100 tweets for @elongmusk. Getting 100 tweets for @StephenColletti. Getting 100 tweets for @jem. Getting 100 tweets for @tonyparker. Getting 100 tweets for @vitorbelfort. Getting 100 tweets for @jeff_green22. Getting 100 tweets for @TomJackson57. Getting 100 tweets for @robbiewilliams. Getting 100 tweets for @AshleyMGreene. Getting 100 tweets for @edhornick. Getting 100 tweets for @mattdusk. Getting 100 tweets for @ReggieEvans30. Getting 100 tweets for @RachelNichols1. Getting 100 tweets for @AndersFoghR. Getting 100 tweets for @PalmerReport. Getting 100 tweets for @KAKA. Getting 100 tweets for @Robbie_OC. Getting 100 tweets for @josiahandthe. Getting 100 tweets for @OKKenna. Getting 100 tweets for @CP3. Getting 100 tweets for @crystaltamar. Getting 100 tweets for @MichelleDBeadle. Getting 100 tweets for @Jonnyboy77. Getting 100 tweets for @kramergirl. Getting 100 tweets for @johnwoodRTR. Getting 100 tweets for @StevePeers. Getting 100 tweets for @AdamSchefter. Getting 100 tweets for @georgelopez. Getting 100 tweets for @CharlieDavies9. Getting 100 tweets for @Nicole_Murphy. Getting 100 tweets for @vkhosla. Getting 100 tweets for @NathanPacheco. Getting 100 tweets for @SomethingToBurn. Getting 100 tweets for @jensstoltenberg. Getting 100 tweets for @Devonte_Riley. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @FreddtAdu. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Erik_Seidel. Getting 100 tweets for @Pamela_Brunson. Getting 100 tweets for @MMRAW. Getting 100 tweets for @russwest44. Getting 100 tweets for @shawnieora. Getting 100 tweets for @wingoz. Getting 100 tweets for @ToddBrunson. Getting 100 tweets for @NathanFillion. Getting 100 tweets for @LaurenLondon. Getting 100 tweets for @francescadani. Getting 100 tweets for @howardhlederer. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @MrBlackFrancis. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @GordonKljestan. Getting 100 tweets for @thehitwoman. Getting 100 tweets for @KeriHilson. Getting 100 tweets for @druidDUDE. Getting 100 tweets for @jimjonescapo. Getting 100 tweets for @myfamolouslife. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @PAULVANDYK. Getting 100 tweets for @SteveAustria. Getting 100 tweets for @bandofhoreses. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @jaysean. Getting 100 tweets for @justdemi. Getting 100 tweets for @MaryBonoUSA. Getting 100 tweets for @PaulBrounMD. Getting 100 tweets for @jrich23. Getting 100 tweets for @Eve6. Getting 100 tweets for @st_vincent. Getting 100 tweets for @Padmasree. Getting 100 tweets for @jamiecullum. Getting 100 tweets for @GuyKawasaki. Getting 100 tweets for @PythonJones. Getting 100 tweets for @sffed. Getting 100 tweets for @howardlindzon. Getting 100 tweets for @xonecole. Getting 100 tweets for @AlisonSudol. Getting 100 tweets for @SuzyWelch. Getting 100 tweets for @topchefkevin. Getting 100 tweets for @MarcusCooks. Getting 100 tweets for @Rick_Bayless. Getting 100 tweets for @ShaniDavis. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @scottylago. Getting 100 tweets for @danielralston. Getting 100 tweets for @crystalshawanda. Getting 100 tweets for @TheRealSimonCho. Getting 100 tweets for @ItsStephRice. Getting 100 tweets for @IvanBabikov. Getting 100 tweets for @DennyMdotcom. Getting 100 tweets for @TFletchernordic. Getting 100 tweets for @RockneBru86. Getting 100 tweets for @JuliaMancuso. Getting 100 tweets for @RyanOBedford. Getting 100 tweets for @speedchick428. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @JennHeil. Getting 100 tweets for @katadamek. Getting 100 tweets for @kathryn_kang. Getting 100 tweets for @alejandrina_gr. Getting 100 tweets for @RaymondArroyo. Getting 100 tweets for @JonHaidt. Getting 100 tweets for @DKShrewsbury. Getting 100 tweets for @faisalislam. Getting 100 tweets for @miqdaad. Getting 100 tweets for @michikokakutani. Getting 100 tweets for @mehdirhasan. Getting 100 tweets for @AbiWilks. Getting 100 tweets for @hugorifkind. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @kylegriffin1. Getting 100 tweets for @timothy_stanley. Getting 100 tweets for @NAXWELL. Getting 100 tweets for @PT_Dawson. Getting 100 tweets for @MaiaDunphy. Getting 100 tweets for @zachheltzel. Getting 100 tweets for @KatyWellhousen. Getting 100 tweets for @NicholasHoult. Getting 100 tweets for @ryanbroems. Getting 100 tweets for @LlamaGod. Getting 100 tweets for @boozan. Getting 100 tweets for @DarrenMattocks. Getting 100 tweets for @BraulioAmado. Getting 100 tweets for @bernierobichaud. Getting 100 tweets for @ThisisSIBA. Getting 100 tweets for @Jill_Perkins3. Getting 100 tweets for @D_Breitenstein. Getting 100 tweets for @George_McD. Getting 100 tweets for @RedAlurk. Getting 100 tweets for @NickRobertson10. Getting 100 tweets for @kevinvu. Getting 100 tweets for @Henry_Kaye. Getting 100 tweets for @Chris_Biele. Getting 100 tweets for @tom_watson. Getting 100 tweets for @MikeSegalov. Getting 100 tweets for @edballs. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @TalbertSwan. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @eugenegu. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Weinsteinlaw. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @BrittMcHenry. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @ava. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @McFaul. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DaShanneStokes. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @funder. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @BrunoAmato_1. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DirkBlocker. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @TrevDon. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DavidYankovich. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @KirkDBorne. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @JohnLegere. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @JustinPollard. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @MattDudek. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @CoachWash56. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @RexxLifeRaj. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @SageRosenfels18. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @oovoo_javer_ceo. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @slactochile. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @jaymijams. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @ChefDoubleG. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @mrpotato. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Rcontreras777. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @MissMaseline. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @mike434prof. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @NonativeEuan. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @mbspyder. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @vaggar99. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @AfifaAssel. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @esruben. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Victorhuvaldez. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @JesiaQuispe. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @TurnbowRosemary. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @todaav. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Pasho53013866. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @tonyaba18632641. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @ghostsignal1. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @chubbyleena. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @genre_addis. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DarrrellWalraven. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @onegearrico. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @abadreen. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @somerice. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @unsaltCarthage. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Cmiln01. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Kitter_44. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @ashish3vedi. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @HugoMunissa. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @TODthegiant. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @LissyBee4. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @anna_adamcova. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @jerwinbroas2. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Queenprominent. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @IndianhawkFB. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @7998472. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @rjerome217. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @CharlesNcharg14. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Truthseeker1237. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @guywpt. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @bernoroel. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DavidOrr4. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @backworldsman1. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @jimmythecoat. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @wrwveit. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @TriggaGhj. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @duckmesick. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @tyjopow. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @mskoch. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @jaspect_wan. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @WiseSparticus. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Mr_AdiSingh. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Live9Fortknox. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @mrfridberg. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @vibolnet. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @paulanderson801. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Supanovawhatevs. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @politicalpatfan. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DAvidofny1. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Tvat_64. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @S_Nenov. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @HglundNiklas. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @LBoertjes. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @anBiabhail. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @iantuck99. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @JumahSaisi. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @QteleOluwatobi1. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @woodgrovect. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @LeeThecritch. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @mkinisa1. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Anfieldvianne. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DonUbani. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @JardyRaines. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @BagbyCarole. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @JopiHuangShen. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @scottwms84. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @gander99. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @biller_jon. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @aeal_ve. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @DesjardinsKarla. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @LBonxe. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @joey_gomez. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @anthoamick844. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Brettwadeart. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @zac_slocumb. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @NatoNogo. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Twu76. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Monoclops37. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @dwhite612. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @_bwright. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @InsaneGamer1983. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @AsaWatts6. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @Niallpolke. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @84newsnerny. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @BrownWilliamF. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @MariusD53205774. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception

# %%
# Get verified users, write them to HD
v_tweet_df, v_user_df  = get_tweets(twitter_client,v_user_list, num_tweets)

user_json = v_user_df.to_json(orient='records')
tweet_json = v_tweet_df.to_json(orient='records')

with open('v_tweet_table_out.json', 'w') as outfile:  
    json.dump(tweet_json, outfile)
with open('v_user_table_out.json', 'w') as outfile:  
    json.dump(user_json, outfile)
# Out:
# Getting 100 tweets for @BarackObama. Getting 100 tweets for @rihanna. Getting 100 tweets for @realDonaldTrump. Getting 100 tweets for @secupp. Getting 100 tweets for @ChairmanKimNK. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @taylorswift13. Getting 100 tweets for @ladygaga. Getting 100 tweets for @TheEllenShow. Getting 100 tweets for @Cristiano. Getting 100 tweets for @YouTube. Getting 100 tweets for @katyperry. Getting 100 tweets for @jtimberlake. Getting 100 tweets for @KimKardashian. Getting 100 tweets for @ArianaGrande. Getting 100 tweets for @britneyspears. Getting 100 tweets for @cnnbrk. Getting 100 tweets for @BillGates. Getting 100 tweets for @narendramodi. Getting 100 tweets for @Oprah. Getting 100 tweets for @SecPompeo. Getting 100 tweets for @nikkihaley. Getting 100 tweets for @SamSifton. Getting 100 tweets for @FrankBruni. Getting 100 tweets for @The_Hank_Poggi. Getting 100 tweets for @krassenstein. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @TheJordanRachel. Getting 100 tweets for @MrsScottBaio. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for @ClaireBerlinski. Getting 100 tweets for @java. Getting 100 tweets for @JakeSherman. Getting 100 tweets for @jaketapper. Getting 100 tweets for @jakeowen. Getting 100 tweets for @AndrewCMcCarthy. Getting 100 tweets for @tictoc.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f87489650ea7> in <module>()
#       1 # Get verified users, write them to HD
# ----> 2 v_tweet_df, v_user_df  = get_tweets(twitter_client,v_user_list, num_tweets)
#       3
#       4 user_json = v_user_df.to_json(orient='records')
#       5 tweet_json = v_tweet_df.to_json(orient='records')
#
# <ipython-input-2-6782bef81dc5> in get_tweets(twitter_client, v_user_list, num_tweets)
#       4 # Helper function to get fixed number of tweets and put in results
#       5 def get_tweets(twitter_client,v_user_list, num_tweets):
# ----> 6     statuses = get_user_timeline_tweets(twitter_client,v_user_list, num_tweets)
#       7
#       8     # Create list to write to json file
#
# <ipython-input-10-491809fe199f> in get_user_timeline_tweets(twitter_client, user_list, num_tweets)
#      21         print(f'Getting {num_tweets} tweets for {user}. ', end = '')
#      22         try:
# ---> 23             for tweet in tp.Cursor(twitter_client.user_timeline, id=user).items(num_tweets):
#      24                 tweets.append(tweet)
#      25         except tp.RateLimitError:
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %%
user_df = nv_user_df.append(v_user_df) #, ignore_index=True)
tweet_df = nv_tweet_df.append(v_tweet_df) #, ignore_index=True)

b_tweet_df = pd.read_json(tweet_json)
b_user_df = pd.read_json(user_json)

# %%
with open('data/b_tweet_table_out.json') as json_file:  
    tweet_json = json.load(json_file)

with open('data/b_user_table_out.json') as json_file:  
    user_json = json.load(json_file)
    
tweets_Clean = pd.read_json(tweet_json)
bots_Clean = pd.read_json(user_json)


final_user_dffinal_us  = user_df.append(bots_Clean)
final_tweet_df = tweet_df.append(tweets_Clean)


with open('data/final_tweet_master.json', 'w') as outfile:  
    json.dump(tweet_json, outfile)
    
with open('data/final_user_master.json', 'w') as outfile:  
    json.dump(user_json, outfile)

# Uncomment above if you'd like to save the data.
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
len(final_user_dffinal_us)
# Out:
# 17486

# %%
final_user_dffinal_us.groupby(final_user_dffinal_us.columns.tolist(),as_index=False).size()
# Out:
# created_at           description                                                                                                                                                       favourites_count  followers_count  id            known_bot  lang  listed_count  location                   name                screen_name      statuses_count  time_zone                    verified
# 2009-05-09 15:58:34  here i am~                                                                                                                                                        0.0               14.0             3.887576e+07  True       ru    0.0           St-Petersburg              Olga                Leecory          219.0           St. Petersburg               0.0         1
# 2011-02-04 06:38:45  Rebecca Lynn Hirschfeld Actress.Model.Writer.Amateur Race Car Driver. ~ Adorkable                                                                                 7273.0            650.0            2.471657e+08  True       en    30.0          Chicago, IL                B E C K S T E R✨    Beckster319      6742.0          Mountain Time (US & Canada)  0.0         1
# 2012-01-23 10:26:25  Честь имею. Нагло врать не умею.                                                                                                                                  1480.0            23305.0          4.718689e+08  True       ru    231.0         Санкт-Петербург, Россия    Маргарита Саваж     MargoSavazh      18401.0         Volgograd                    0.0         1
# 2012-12-27 13:06:58  uptodate news!!!!                                                                                                                                                 0.0               22.0             1.039581e+09  True       id    16.0          Amerika                    Dark Nally          darknally        22603.0         Jakarta                      0.0         1
# 2013-06-11 15:38:17  Slave blood. Melanin. Water. Fire. Honey\n#BlackLivesMatter bih                                                                                                   1882.0            1000.0           1.504356e+09  True       en    14.0          USA                        Eliana Galloway     GallowayEliana   1721.0          Eastern Time (US & Canada)   0.0         1
# 2013-06-12 13:07:49  How can you judge me when you don’t know me?                                                                                                                      3504.0            3080.0           1.510489e+09  True       en    12.0          USA                        Laila Heats         lagonehoe        2228.0          Eastern Time (US & Canada)   0.0         1
# 2013-06-13 16:07:23  ProBlack | Stoner | even jesus was stoned before receiving the throne | #BlackToLive | #BlackLivesMatter                                                          2744.0            2760.0           1.513801e+09  True       en    10.0          USA                        CC Jack             YouJustCtrlC     2100.0          Eastern Time (US & Canada)   0.0         1
# 2013-06-14 21:58:48  I'm getting too cool for this social media shiz. That cynical bastard you hate to love.                                                                           2981.0            879.0            1.517679e+09  True       en    15.0          Philadelphia, PA           Mr Moran            MrMoraan         2044.0          Eastern Time (US & Canada)   0.0         1
# 2013-06-15 08:47:02  Strive not to be a success but rather to be of value #blm #BforLife                                                                                               2170.0            789.0            1.518857e+09  True       en    8.0           USA                        Jonathon Norwood    NoJonathonNo     2002.0          Eastern Time (US & Canada)   0.0         1
# 2013-06
x.head()
# Out:
#             created_at                        description  favourites_count  \
# 0  2007-03-05 22:08:25  Dad, husband, President, citizen.              11.0
# 1  2007-03-05 22:08:25  Dad, husband, President, citizen.              11.0
# 2  2007-03-05 22:08:25  Dad, husband, President, citizen.              11.0
# 3  2007-03-05 22:08:25  Dad, husband, President, citizen.              11.0
# 4  2007-03-05 22:08:25  Dad, husband, President, citizen.              11.0
#
#    followers_count        id  known_bot  lang  listed_count        location  \
# 0      110312767.0  813286.0      False  None      228446.0  Washington, DC
# 1      110312767.0  813286.0      False  None      228446.0  Washington, DC
# 2      110312767.0  813286.0      False  None      228446.0  Washington, DC
# 3      110312767.0  813286.0      False  None      228446.0  Washington, DC
# 4      110312767.0  813286.0      False  None      228446.0  Washington, DC
#
#            name  screen_name  statuses_count time_zone  verified
# 0  Barack Obama  BarackObama         15688.0      None       1.0
# 1  Barack Obama  BarackObama         15688.0      None       1.0
# 2  Barack Obama  BarackObama         15688.0      None       1.0
# 3  Barack Obama  BarackObama         15688.0      None       1.0
# 4  Barack Obama  BarackObama         15688.0      None       1.0

# %%
x.duplicated(subset='screen_name', keep='first').sum()
# Out:
# 16859

# %%
x.drop_duplicates(inplace=True)

# %%
len(x)
# Out:
# 644

# %%
x.to_csv("user_list.csv",index = None, header=True)

# %%
bots = [
'@andrebeauleger',
'@angelabach991',
'@AnthonyWoodboy', 
'@_Billy_Moyer_',
'@c__wells',
'@christinapool61',
'@evewebster373',
'@fishalexanderr',
'@Jamie_Mccarthy_',
'@KarolineAuge',
'@LilyLilyhasse',
'@Logan_WhatsUp',
'@manuelkrosss',
'@MicParrish',
'@NinonDerrien',
'@sylvielefevrier',
'@verrellportier',
'@LelandGraves_',
'@GlennHarper_',
'@TodayCleveland',
'@iris0_o',
'@ClydeDaws0n',
'@Joseph_Jenks',
'@Erdollum666',
'@EricaRutter',
'@riogithief',
'@JaedenMassey',
'@IanCalh0un',
'@MilwaukeeVoice',
'@portmela',
'@BeverlyBalsom',
'@ssus_panther',
'@ChristinaCrisss',
'@JsnCarey',
'@ColbyST1',
'@AlbertMoreNMore',
'@Roscoe_Riddle',
'@Israel_Wills',
'@OrrClay',
'@agnesgrhm',
'@RyannCooperwood',
'@Gibbs_Jeremy_',
'@GraceLilStar',
'@wildharee',
'@handsome_henson',
'@Danny_Turner_1',
'@jrrbrtt',
'@Jon_Underwood_',
'@EdmundC0oke',
'@SindyBlossom',
'@sto_christi',
'@YaelTrouble',
'@KristyanaNN',
'@T0nyaSinclair',
'@KimberleighLamb',
'@HamburgBote',
'@ReachItDoIt',
'@KirstenLaDaniel',
'@gwen_garland',
'@KlausFinker',
'@srahSE'
]

# %%
nt_tweet_df, nt_user_df  = get_tweets(twitter_client,bots, num_tweets)
# Out:
# Getting 100 tweets for id. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for location. Getting 100 tweets for name. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for followers_count. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for statuses_count. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for time_zone. Getting 100 tweets for verified. Getting 100 tweets for lang. Getting 100 tweets for screen_name. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for description. Getting 100 tweets for created_at. Getting 100 tweets for favourites_count. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for friends_count. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
# Getting 100 tweets for listed_count. SOME ERROR OCCURRED...PASSING!!!
# Tweepy exception
